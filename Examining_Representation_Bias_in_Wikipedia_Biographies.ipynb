# %% [markdown]
# <a href="https://colab.research.google.com/github/aysegulguzel/aysegulguzel/blob/main/Examining_Representation_Bias_in_Wikipedia_Biographies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Disaggregators is a library developed by Hugging Face. As the name implies, it "dis-aggregates" data so that we can explore the data in more granular detail and evaluate data bias

# %%
pip install datasets disaggregators==0.1.2
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: disaggregators==0.1.2 in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (24.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (3.5.4)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (3.1.15)
# Requirement already satisfied: sentence-transformers>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (2.6.1)
# Requirement already satisfied: geograpy3 in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (0.2.7)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from disaggregators==0.1.2) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->disaggregators==0.1.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->disaggregators==0.1.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->disaggregators==0.1.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->disaggregators==0.1.2) (2024.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->disaggregators==0.1.2) (4.38.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->disaggregators==0.1.2) (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->disaggregators==0.1.2) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->disaggregators==0.1.2) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->disaggregators==0.1.2) (9.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (1.10.15)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->disaggregators==0.1.2) (3.3.0)
# Requirement already satisfied: newspaper3k>=0.2.8 in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (0.2.8)
# Requirement already satisfied: jellyfish>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (1.0.3)
# Requirement already satisfied: pylodstorage>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (0.10.3)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (2.0.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (2.3.0)
# Requirement already satisfied: OSMPythonTools>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from geograpy3->disaggregators==0.1.2) (0.3.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->disaggregators==0.1.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->disaggregators==0.1.2) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->disaggregators==0.1.2) (2023.12.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (4.12.3)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (4.9.4)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (5.1.2)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (0.35.1)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (0.3)
# Requirement already satisfied: geojson in /usr/local/lib/python3.10/dist-packages (from OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (3.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (3.8.4)
# Requirement already satisfied: ujson in /usr/local/lib/python3.10/dist-packages (from OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (5.9.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (2023.7.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy->disaggregators==0.1.2) (0.1.1)
# Requirement already satisfied: dacite>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (1.8.1)
# Requirement already satisfied: dataclasses-json>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (0.6.4)
# Requirement already satisfied: dicttoxml2 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (2.1.0)
# Requirement already satisfied: jsonpickle==1.5.2 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (1.5.2)
# Requirement already satisfied: orjson>=3.9.15 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (3.10.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (2.16.1)
# Requirement already satisfied: pylatexenc~=2.10 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (2.10)
# Requirement already satisfied: pyparsing>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (3.1.2)
# Requirement already satisfied: python-slugify>=8.0.1 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (8.0.4)
# Requirement already satisfied: sparqlwrapper>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (2.0.0)
# Requirement already satisfied: sqlmodel>=0.0.16 in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (0.0.16)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (0.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.2->disaggregators==0.1.2) (3.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->disaggregators==0.1.2) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->disaggregators==0.1.2) (0.1.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (12.4.127)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (0.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->geograpy3->disaggregators==0.1.2) (2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->disaggregators==0.1.2) (2.1.5)
# Requirement already satisfied: sphinx<8,>=5 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (5.0.2)
# Requirement already satisfied: docutils<0.21 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (0.18.1)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (4.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.3->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.3->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (0.9.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser>=5.2.1->newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->OSMPythonTools>=0.3.3->geograpy3->disaggregators==0.1.2) (1.4.5)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify>=8.0.1->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (1.3)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.10/dist-packages (from sparqlwrapper>=2.0.0->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (7.0.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.0.7)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (2.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (0.7.16)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=5->sphinx-rtd-theme->geograpy3->disaggregators==0.1.2) (1.4.1)
# Requirement already satisfied: SQLAlchemy<2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sqlmodel>=0.0.16->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (2.0.29)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k>=0.2.8->geograpy3->disaggregators==0.1.2) (2.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.2.2->disaggregators==0.1.2) (1.3.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->sparqlwrapper>=2.0.0->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (0.6.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<2.1.0,>=2.0.0->sqlmodel>=0.0.16->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.3->pylodstorage>=0.4.7->geograpy3->disaggregators==0.1.2) (1.0.0)

# %% [markdown]
# There are multiple disaggregation modules available: age, gender, religion, continent, pronoun
#
# Let´s check the pronoun granularity.

# %%
from disaggregators import Disaggregator

disaggregator = Disaggregator("pronoun", column="target_text")

# %% [markdown]
# Let´s use Wikipedia biographies dataset, wiki_bio, from Hugging Face Datasets.
#
# The disaggregators library endeavors to categorize the wiki bios into she_her, he_him, and they_them groups.

# %%
from datasets import load_dataset

wiki_data = load_dataset(
    "wiki_bio", split="test"
)  #
ds = wiki_data.map(disaggregator)
pdf = ds.to_pandas()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/72831 [00:00<?, ? examples/s]

# %%
# Let's take a look at the dataframe
pdf
# Out:
#                                               input_text  \
# 0      {'table': {'column_header': ['finalyear', 'bat...
# 1      {'table': {'column_header': ['caption', 'const...
# 2      {'table': {'column_header': ['birth_place', 'n...
# 3      {'table': {'column_header': ['death_date', 'na...
# 4      {'table': {'column_header': ['associated_acts'...
# ...                                                  ...
# 72826  {'table': {'column_header': ['finalyear', 'bat...
# 72827  {'table': {'column_header': ['serviceyears', '...
# 72828  {'table': {'column_header': ['birth_place', 'n...
# 72829  {'table': {'column_header': ['birth_place', 'b...
# 72830  {'table': {'column_header': ['fullname', 'yout...
#
#                                              target_text  pronoun.she_her  \
# 0      leonard shenoff randle -lrb- born february 12 ...            False
# 1      philippe adnot -lrb- born 25 august 1945 in rh...            False
# 2      miroslav popov -lrb- born 14 june 1995 in dvůr...            False
# 3      john `` jack '' reynolds -lrb- 21 february 186...            False
# 4      william ato ankrah , -lrb- born 7th july 1979 ...            False
# ...                                                  ...              ...
# 72826  vernon scot thompson -lrb- born december 7 , 1...            False
# 72827  shabtai shavit -lrb- ; born 17 july 1939 -rrb-...            False
# 72828  cesar andrade is a brazilian professional vert...            False
# 72829  moulay hafid elalamy -lrb- born 1960 -rrb- is ...            False
# 72830  ashley james corker -lrb- born 18 september 19...            False
#
#        pronoun.he_him  pronoun.they_them
# 0                True              False
# 1                True              False
# 2                True              False
# 3                True              False
# 4                True              False
# ...               ...                ...
# 72826            True              False
# 72827            True              False
# 72828            True              False
# 72829            True              False
# 72830            True              False
#
# [72831 rows x 5 columns]

# %% [markdown]
# As it does not do a good job with they/them, we will ignore it

# %%
import numpy as np

she_array = np.where(pdf["pronoun.she_her"] == True)
print(f"she_her: {len(she_array[0])} rows")
he_array = np.where(pdf["pronoun.he_him"] == True)
print(f"he_him: {len(he_array[0])} rows")
# Out:
# she_her: 9545 rows
# he_him: 44004 rows

# %% [markdown]
# OK THIS IS SOMETHING!!!!
# WIKI-BIO DATASET (BIOS FROM WIKIPEDIA) TEST SET IN HUGGINGFACE HUB, HAS 9545 SHE-HER AND 44004 HE-HIM!
#
# WHEN WE TALK ABOUT BIAS WE ARE TALKING ABOUT THIS. THE LARGE LANGUAGE MODELS ARE NOT MAGIC. THEY ARE SIMPLY TRYING TO PREDICT THE NEXT WORD AFTER THE SEQUENCE FROM THE WHOLE VOCABULARY YOU GAVE TO THEM. IF YOU GAVE THEM 9545 WOMAN BIO INSTEAD OF 44004 MEN BIO, THE MODEL PREDICTIONS WILL BE .
#
# THE HE/HIM PRONOUN DATA REPRESENTS 44004/ (9545+44004) = 82% OF THE DATA. THE MODELS TRAINED ON MOSTLY ON MEN DATA WOULD EXHIBIT BIAS TOWARD MALES
#
#
# LET´S CHECK WHAT THE MODELS PREDICT THEN!LET´S CHECK IT IN BERT MODEL, AS WE KNOW THAT BERT IS TRAINED ON WIKIPEDIA DATA FOR EXAMPLE.

# %%
from transformers import pipeline

unmasker = pipeline(
    "fill-mask",
    model="bert-base-uncased"
)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# To probe what BERT outputs, we will intentionally insert [MASK] token and ask BERT to generate words to replace that [MASK] token.

# %%
result = unmasker("This woman works as a [MASK].")
print([r["token_str"] for r in result])

result = unmasker("This man works as a [MASK].")
print([r["token_str"] for r in result])
# Out:
# ['nurse', 'maid', 'teacher', 'waitress', 'prostitute']
# ['carpenter', 'lawyer', 'farmer', 'businessman', 'doctor']

# %% [markdown]
# YEP THAT IS IT! THIS IS VERY SIMPLE SIMULATION OF HOW BIAS WORKS IN LESS THAN 2 MINUTES. AND WE CAN PREVENT THIS BIAS AND CREATE A MUCH MORE DATASET ALL TOGETHER, THERE IS NOT A EASY FIX OF IT.
#
# JESSICA WADE CAN BE AN INSPIRATION FOR US!
#
#
# > I’ve Made More Than 1,700 Wikipedia Entries on Women Scientists and I’m Not Yet Done!
# [British scientist Jessica Wade has made one Wikipedia entry every day since 2017](https://www.vice.com/en/article/z34k9e/wikipedia-pages-women-scientists-jessica-wade-stem)
#
#
# AND THE BIASES WE SEE IN AI IS JUST THE REFLECTION OF THE BIASES THAT EXIST IN HUMAN LIFE, ALL AROUND THE GLOBE. IT IS NOT THAT EASY TO FIX WITH CODING, PREPARING DATASET ETC.
#
# FOR THAT WE NEED TO WORK ALLTOGETHER AS A COMMUNITY MY FRIEND.
#
#
# ---
